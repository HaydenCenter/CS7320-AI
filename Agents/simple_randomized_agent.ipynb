# %% [markdown]
# # Intelligent Agents: Reflex Agents for the Vacuum-cleaner World
#
#
# ## Instructions
#
# Total Points: undergrad 10, graduate students 11
#
# Complete this notebook and submit it. The notebook needs to be a complete project report with
#
# * your implementation,
# * documentation including a short discussion of how your implementation works and your design choices, and
# * experimental results (e.g., tables and charts with simulation results) with a short discussion of what they mean.
#
# Use the provided notebook cells and insert additional code and markdown cells as needed.
#
# ## Introduction
#
# In this assignment you will implement a simulator environment for an automatic vacuum cleaner robot, a set of different reflex agent programs, and perform a comparison study for cleaning a single room. Focus on the __cleaning phase__ which starts when the robot is activated and ends when the last dirty square is cleaned. Someone else will take care of the agent program needed to navigate back to the charging station after the room is clean.
#
# ## PEAS description of the cleaning phase
#
# __Performance Measure:__ Each action costs 1 energy unit. The performance is measured as the sum of the energy units used to clean the whole room.
#
# __Environment:__ A room with $n \times n$ squares where $n = 5$. Dirt is randomly placed on each square with probability $p = 0.2$. For simplicity, you can assume that the agent knows the size and the layout of the room (i.e., it knows $n$). To start, the agent is placed on a random square.
#
# __Actuators:__ The agent can `clean` the current square or move to an adjacent square by going `north`, `east`, `south`, or `west`.
#
# __Sensors:__ Four bumper sensors, one for north, east, south, and west; a dirt sensor reporting dirt in the current square.
#
#
# ## The agent program for a simple randomized agent
#
# The agent program is a function that gets sensor information (the current percepts) as the arguments. The arguments are:
#
# * A dictionary with boolean entries for the for bumper sensors `north`, `east`, `west`, `south`. E.g., if the agent is on the north-west corner, `bumpers` will be `{"north" : True, "east" : False, "south" : False, "west" : True}`.
# * The dirt sensor produces a boolean.
#
# The agent returns the chosen action as a string.
#
# Here is an example implementation for the agent program of a simple randomized agent:

# %%
from numpy import random

actions = ["north", "east", "west", "south", "suck"]

def simple_randomized_agent(bumpers, dirty):
    return random.choice(actions)

# %%
# define percepts (current location is NW corner and it is dirty)
bumpers = {"north" : True, "east" : False, "south" : False, "west" : True}
dirty = True

# call agent program function with percepts and it returns an action
simple_randomized_agent(bumpers, dirty)
# Out:
# 'west'

# %% [markdown]
# __Note:__ This is not a rational intelligent agent. It ignores its sensors and may bump into a wall or not clean a dirty square. You will be asked to implement rational agents below.

# %% [markdown]
# ## Simple environment example
#
# This simple environment is infinite in size (bumpers are always `False`) and every square is always dirty, even if the agent cleans it. The environment function returns the performance measure which is here the number of cleaned squares (since all squares are constantly dirty, it is the number of `suck` actions by the agent).

# %%
def simple_environment(agent, max_steps, verbose = True):
    num_cleaned = 0
    
    for i in range(max_steps):
        dirty = True
        bumpers = {"north" : False, "south" : False, "west" : False, "east" : False}

        action = agent(bumpers, dirty)
        if (verbose): print("step", i , "- action:", action) 
        
        if (action == "suck"): 
            num_cleaned = num_cleaned + 1
        
    return num_cleaned

# %% [markdown]
# Do one simulation run with 20 steps.

# %%
simple_environment(simple_randomized_agent, max_steps = 20)
# Out:
# step 0 - action: west
# step 1 - action: north
# step 2 - action: suck
# step 3 - action: west
# step 4 - action: east
# step 5 - action: north
# step 6 - action: east
# step 7 - action: east
# step 8 - action: west
# step 9 - action: suck
# step 10 - action: east
# step 11 - action: west
# step 12 - action: east
# step 13 - action: south
# step 14 - action: south
# step 15 - action: suck
# step 16 - action: north
# step 17 - action: west
# step 18 - action: east
# step 19 - action: suck
# 4

# %% [markdown]
# # Tasks
#
# _Submission Instructions:_ Use this notebook to prepare your submission. Complete this section with your code and results. You can add additional Markdown blocks for your description, comments in the code and use mathplotlib to produce charts.
#
# _Note:_ Try to keep the code simple! In this course, we want to learn about the algorithms and we often do not need to use object-oriented design.
#
#
# ## Task 1: Implement a simulation environment [2 Points]
#
# The simple environment above is not very realistic. Your environment simulator needs to follow the PEAS description from above. It needs to:
#
# * Initialize the environment by storing the state of each square (clean/dirty) and making some dirty.
# * Keep track of the agent's position.
# * Call the agent function repeatedly and provide the agent function with the sensor inputs.
# * React to the agent's actions. E.g, by removing dirt from a square or moving the agent around unless there is a wall in the way.
# * Keep track of the performance measure. That is, track the agent's actions until all dirty squares are clean and count the number of actions it takes the agent to complete the task.
#
# The easiest implementation for the environment is to hold an 2-dimensional array to represent if squares are clean or dirty and to call the agent function in a loop until all squares are clean or a predefined number of steps have been reached (i.e., the robot runs out of energy).
#
# The simulation environment needs to work with the simple randomized agent program from above and then it can be used for your agent implementation in the tasks below.

# %%
import numpy as np

def environment(agent, n = 5, p = 0.2, x = random.choice(a=range(5)),
                y = random.choice(a=range(5)), max_steps = 100, verbose = True):
    
    ground = random.choice(a=[False, True], size=(n, n), p=[1-p, p])
    
    
    
    
    step = 0
        
    while np.count_nonzero(ground) > 0 and step < max_steps:
        bumpers = {
            'north': False,
            'south': False,
            'east': False,
            'west': False,
        }
            
        if x == 0:
            bumpers['north'] = True
        elif x == n - 1:
            bumpers['south'] = True
        
        if y == 0:
            bumpers['west'] = True
        elif y == n - 1:
            bumpers['east'] = True
            
        dirty = ground[x][y]
        action = agent(bumpers, dirty)
        if verbose: print("step", step ,"- position", x, ", ", y, "- action:", action)
        
        if action == 'suck':
            ground[x][y] = False
        elif action == 'north':
            x -= 1
        elif action == 'south':
            x += 1
        elif action == 'east':
            y += 1
        elif action == 'west':
            y -= 1
            
        if x > n - 1:
            x = n - 1
        elif x < 0:
            x = 0
            
        if y > n - 1:
            y = n - 1
        elif y < 0:
            y = 0
            
        step += 1
        
    return step

# %% [markdown]
# ## Task 2:  Implement a simple reflex agent [1 Point]
#
# The simple reflex agent randomly walks around but reacts to the bumper sensor by not bumping into the wall and to dirt with sucking. Implement the agent program as a function.
#
# _Note:_ The agent cannot directly use variable in the environment. It only gets the percepts as the arguments to the agent program function.

# %%
def simple_reflex_agent(bumpers, dirty):
    if dirty:
        return 'suck'
    
    actions = []
    
    for direction, bumper in bumpers.items():
        if not bumper:
            actions.append(direction)
            
    if actions:
        return random.choice(actions)
    else:
        return 'suck'

# %% [markdown]
# ## Task 3: Implement a model-based reflex agent [3 Point]
#
# This agent keeps track of the location and remembers where it has cleaned. Assume the agent knows how many squares the room has. It can move to a corner to determine its location and then is able to use more advanced navigation.
#
# Describe how you define the __agent state__ and how your agent works before implementing it. _Note on implementing the state in Python:_ [Examples](https://github.com/mhahsler/CS7320-AI/blob/master/Python_Code_Examples/store_agent_state_information.ipynb)

# %% [markdown]
# The state of my model-based reflex agent is a bit more complex than simply tracking its position. The first component of the state is, however, position data, in the form of an *x* value, a *y* value, and *n*, which is the size of the *n* x *n* grid. Secondly, my implementation makes use of direction, which makes navigating the grid a bit simpler. The state also stores a *n* x *n* boolean array to track whether or not the agent has visited a square before. Lastly, the agent's state contains information about the nearest corner of the grid and whether or not it has arrived there yet.
#
# This last part of the state allows the agent to navigate to the corner of the grid without marking the squares it passes as "visited". While this is not exactly optimal, and was not my first attempt at a solution, it turns out that in trying to visit no squares twice, starting away from the corner of the grid can sometimes cause the agent to get "stuck" and not be able to find a path away from the previously visited squares.
#
# The agent starts each action by cleaning the square if it is dirty. If the square is clean, and the agent has not yet navigated to the nearest corner, it will advance towards it. Once the agent has reached the corner, the agent then begins marking squares as "visited". The agent proceeds "forward" (initialized as 'north' or in the direction of negative *x*) until the next square in front of it has been visited or is out of the grid (which is checked by the bumpers). If the agent can not proceed forward, it "turns" right (adjusts the directions stored in the state to those right of each one) until it can. Once it can move forward, the agent returns the direction stored in the state as "forward" and updates its *x* and *y* coordinates.
#
# This algorithm visually looks like the agent moving to the neareast corner and then visiting every square in a spiral towards the center, cleaning dirty squares as it passes over them.

# %%
class ModelReflexAgent:
    def __init__(self, x, y, n):
        self.x = x
        self.y = y
        self.n = n
        
        self.forward = 'north'
        self.right   = 'east'
        self.back    = 'south'
        self.left    = 'west'
        
        self.visited = np.full((n, n), False)
        
        self.navigate_to_corner = True
        self.corner_x = (0 if x < (n / 2.0) else n - 1)
        self.corner_y = (0 if x < (n / 2.0) else n - 1)
        
    def act(self, bumpers, dirty):        
        if dirty:
            return 'suck'
        
        if self.navigate_to_corner:
            if self.x > self.corner_x:
                self.x -= 1
                return 'north'
            elif self.x < self.corner_x:
                self.x += 1
                return 'south'
            elif self.y < self.corner_y:
                self.y += 1
                return 'east'
            elif self.y > self.corner_y:
                self.y -= 1
                return 'west'
            else:
                self.navigate_to_corner = False

        self.visited[self.x][self.y] = True
        
        count = 0
        while not self.check(self.forward, bumpers):
            self.turn_right()
            count += 1
            # The agent is stuck if it turns right 4 times and still cannot advance
            # Return action 'suck' to keep it in place until it reaches max_steps
            if count > 4:
                return 'suck'
                            
        return self.advance()
        
    def check(self, direction, bumpers):
        if bumpers[direction]:
            return False
        elif direction == 'north':
            return not self.visited[self.x - 1][self.y]
        elif direction == 'south':
            return not self.visited[self.x + 1][self.y]
        elif direction == 'east':
            return not self.visited[self.x][self.y + 1]
        elif direction == 'west':
            return not self.visited[self.x][self.y - 1]

    def turn_right(self):
        self.forward, self.right, self.back, self.left = self.right, self.back, self.left, self.forward
        
    def advance(self):
        if self.forward == 'north':
            self.x = self.x - 1
        elif self.forward == 'south':
            self.x = self.x + 1
        elif self.forward == 'east':
            self.y = self.y + 1
        elif self.forward == 'west':
            self.y = self.y - 1
        return self.forward

# %% [markdown]
# ## Task 4: Simulation study [3 Points]
#
# Compare the performance (the performance measure is defined in the PEAS description above) of the agents using  environments of different size. E.g., $5 \times 5$, $10 \times 10$ and
# $100 \times 100$. Use 100 random runs for each. Present the results in a suitable format (tables, graphs) and discuss the differences.
#
# Here is some help with [charts and tables.](https://github.com/mhahsler/CS7320-AI/blob/master/Python_Code_Examples/charts_and_tables.ipynb)

# %%
avgs = {
    'rand': {},
    'rflx': {},
    'mbra': {}
}

trials = 100
sizes = [5, 10, 100]

for n in sizes:
    avgs['rand'][n] = {}
    avgs['rflx'][n] = {}
    avgs['mbra'][n] = {}
    avgs['rand'][n]['tot'] = 0
    avgs['rflx'][n]['tot'] = 0
    avgs['mbra'][n]['tot'] = 0
    

    for i in range(trials):
        x = random.choice(a=range(n))
        y = random.choice(a=range(n))
        model_reflex_agent = ModelReflexAgent(x, y, n).act
        
        avgs['rand'][n]['tot'] += environment(simple_randomized_agent,
                                              x = x, y = y, n = n,
                                              max_steps = 5 * (n**2), verbose = False)
        avgs['rflx'][n]['tot'] += environment(simple_reflex_agent,
                                              x = x, y = y, n = n,
                                              max_steps = 5 * (n**2), verbose = False)
        avgs['mbra'][n]['tot'] += environment(model_reflex_agent,
                                              x = x, y = y, n = n,
                                              max_steps = 5 * (n**2), verbose = False)
        
    avgs['rand'][n]['avg'] = avgs['rand'][n]['tot'] / trials
    avgs['rflx'][n]['avg'] = avgs['rflx'][n]['tot'] / trials
    avgs['mbra'][n]['avg'] = avgs['mbra'][n]['tot'] / trials

# %%
avgs

# %% [markdown]
# Fill out the following table with the average performance measure for 100 random runs (you may also create this table with code):
#
# | Size     | Randomized Agent | Simple Reflex Agent | Model-based Reflex Agent |
# |----------|------------------|---------------------|--------------------------|
# | 5x5     | 411.73 | 108.0 | 27.05 |
# | 10x10   | 3006.74 | 881.64 | 122.75 |
# | 100x100 | 846536.08 | 346545.62 | 12062.94 |

# %% [markdown]
# As expected, the model based agent far out performs the reflex based agent, increasingly so as the grid expands. In a 5x5 grid, the MBRA is nearly 4 times as fast as the simple reflex agent, but as the grid quadruples in size (25 to 100 squares), the factor increases to nearly 8 times. Once the grid reaches 10,000 squares, the simple reflex agent is over 28 times slower than the model based agent. I would expect the gap between the model based and simple reflex agent to grow even further when expanding the grid, due to randomness performing much worse as the grid size increases.
#
# Another point of note is that, on average, the model based reflex agent seems to complete cleaning at a little over 1.2 times the number of squares in the grid., which fits very closely to what we would expect, given that it traverse the entire grid, but takes an extra step every time it cleans the approximately 20% of dirty squares. The other variation we likely see is the navigation to the corner introducing extra steps, and the completion of cleaning happening before a full traversal of the grid. I would wager that the larger the grid gets, the more this trend would continue towards a fixed value slightly above *1.2 x n<sup>2</sup>*.

# %% [markdown]
# ## Task 5: Robustness of the agent implementations [1 Point]
#
# Describe how your agent implementations will perform
#
# * if it is put into a rectangular room with unknown size,
# * if the cleaning area can have an iregular shape (e.g., a hallway connecting two rooms), or
# * if the room contains obstacles (i.e., squares that it cannot pass through and trigger the bumper sensors).

# %% [markdown]
# ### Answer
# * My agent would, with a slight tweak to the corner navigation section of the algorithm, perform excellently in a room of unknown size. The only hiccup in its current iteration would be that it needs to know the size of the room n to determine which corner is nearest to its current position, but simply changing that code to navigate to 0,0 every time would fix that issue.
# * My agent would be able to generally perform well in this environment with the same tweak mentioned above, however there definitely would be issues with some room configurations. Firstly, if there were an obstacle in the way of the agent's starting position and the top corner of the room, the agent may miss a signigicant portion of the room, or in other cases, such as a hallway one square wide, the agent might get itself stuck on one side of the room.
# * A room that contains obstacles would likely provide a similar issue as the previous alteration, creating problems by forcing the agent to cut its own path off. The concept of visiting each square only once does not work perfectly for all shapes, but specifically works for an open square, so any variation on the shape of the environment (excluding simply scaling the environment) will result in similar issues.

# %% [markdown]
# ## Graduate student advanced task: Obstacles [1 Point]
#
# __Undergraduate students:__ This is a bonus task you can attempt if you like [+1 Bonus point].
#
# 1. Change your simulation environment tor run experiments for the following problem: Add random obstacle squares that also trigger the bumper sensor. The agent does not know where the obstacles are. Observe how this changes the performance of the three implementations.
#
# 2. Describe what would need to be done to perform better with obstacles. Add code if you can.

# %%
import numpy as np

def obstacle_environment(agent, n = 5, p = 0.2, x = random.choice(a=range(5)),
                y = random.choice(a=range(5)), max_steps = 100, verbose = True):
    
    ground = random.choice(a=[False, True], size=(n, n), p=[1-p, p])
    
    
    
    
    step = 0
        
    while np.count_nonzero(ground) > 0 and step < max_steps:
        bumpers = {
            'north': False,
            'south': False,
            'east': False,
            'west': False,
        }
        
        ######################################################
        # Changes to add obstacles into environment ##########
        
        obstacles = np.full((n, n), False)
        possible = np.transpose(np.nonzero(np.invert(ground)))
        
        for i in possible:
            if random.choice(int(1/p)) == 0:
                obstacles[i[0]][i[1]] = True
        
        if (x == 0) or (obstacles[x - 1][y]):
            bumpers['north'] = True
        if (x == n) - 1 or (obstacles[x + 1][y]):
            bumpers['south'] = True
        if (y == 0) or (obstacles[x][y - 1]):
            bumpers['west'] = True
        if (y == n - 1) or (obstacles[x][y + 1]):
            bumpers['east'] = True
        
        ######################################################
        
        
        dirty = ground[x][y]
        action = agent(bumpers, dirty)
        if verbose: print("step", step ,"- position", x, ", ", y, "- action:", action)
        
        if action == 'suck':
            ground[x][y] = False
        elif action == 'north':
            x -= 1
        elif action == 'south':
            x += 1
        elif action == 'east':
            y += 1
        elif action == 'west':
            y -= 1
            
        if x > n - 1:
            x = n - 1
        elif x < 0:
            x = 0
            
        if y > n - 1:
            y = n - 1
        elif y < 0:
            y = 0
            
        step += 1
        
    return step

# %%
obst_avgs = {
    'rand': {},
    'rflx': {},
    'mbra': {}
}

trials = 1
sizes = [5, 10, 100]

for n in sizes:
    obst_avgs['rand'][n] = {}
    obst_avgs['rflx'][n] = {}
    obst_avgs['mbra'][n] = {}
    obst_avgs['rand'][n]['tot'] = 0
    obst_avgs['rflx'][n]['tot'] = 0
    obst_avgs['mbra'][n]['tot'] = 0
    

    for i in range(trials):
        x = random.choice(a=range(n))
        y = random.choice(a=range(n))
        model_reflex_agent = ModelReflexAgent(x, y, n).act
        
        obst_avgs['rand'][n]['tot'] += obstacle_environment(simple_randomized_agent,
                                              x = x, y = y, n = n,
                                              max_steps = 5 * (n**2), verbose = True)
        obst_avgs['rflx'][n]['tot'] += obstacle_environment(simple_reflex_agent,
                                              x = x, y = y, n = n,
                                              max_steps = 5 * (n**2), verbose = True)
        obst_avgs['mbra'][n]['tot'] += obstacle_environment(model_reflex_agent,
                                              x = x, y = y, n = n,
                                              max_steps = 5 * (n**2), verbose = True)
        
    obst_avgs['rand'][n]['avg'] = obst_avgs['rand'][n]['tot'] / trials
    obst_avgs['rflx'][n]['avg'] = obst_avgs['rflx'][n]['tot'] / trials
    obst_avgs['mbra'][n]['avg'] = obst_avgs['mbra'][n]['tot'] / trials
# Out:
# step 0 - position 1 ,  4 - action: north
# step 1 - position 0 ,  4 - action: north
# step 2 - position 0 ,  4 - action: east
# step 3 - position 0 ,  4 - action: south
# step 4 - position 1 ,  4 - action: suck
# step 5 - position 1 ,  4 - action: west
# step 6 - position 1 ,  3 - action: north
# step 7 - position 0 ,  3 - action: west
# step 8 - position 0 ,  2 - action: north
# step 9 - position 0 ,  2 - action: east
# step 10 - position 0 ,  3 - action: west
# step 11 - position 0 ,  2 - action: east
# step 12 - position 0 ,  3 - action: suck
# step 13 - position 0 ,  3 - action: west
# step 14 - position 0 ,  2 - action: suck
# step 15 - position 0 ,  2 - action: west
# step 16 - position 0 ,  1 - action: south
# step 17 - position 1 ,  1 - action: west
# step 18 - position 1 ,  0 - action: north
# step 19 - position 0 ,  0 - action: north
# step 20 - position 0 ,  0 - action: suck
# step 21 - position 0 ,  0 - action: west
# step 22 - position 0 ,  0 - action: east
# step 23 - position 0 ,  1 - action: south
# step 24 - position 1 ,  1 - action: suck
# step 25 - position 1 ,  1 - action: west
# step 26 - position 1 ,  0 - action: south
# step 27 - position 2 ,  0 - action: east
# step 28 - position 2 ,  1 - action: west
# step 29 - position 2 ,  0 - action: suck
# step 30 - position 2 ,  0 - action: east
# step 31 - position 2 ,  1 - action: suck
# step 32 - position 2 ,  1 - action: south
# step 33 - position 3 ,  1 - action: south
# step 34 - position 4 ,  1 - action: suck
# step 35 - position 4 ,  1 - action: suck
# step 36 - position 4 ,  1 - action: west
# step 37 - position 4 ,  0 - action: north
# step 38 - position 3 ,  0 - action: suck
# step 39 - position 3 ,  0 - action: suck
# step 40 - position 3 ,  0 - action: east
# step 41 - position 3 ,  1 - action: west
# step 42 - position 3 ,  0 - action: north
# step 43 - position 2 ,  0 - action: suck
# step 44 - position 2 ,  0 - action: west
# step 45 - position 2 ,  0 - action: east
# step 46 - position 2 ,  1 - action: suck
# step 47 - position 2 ,  1 - action: east
# step 48 - position 2 ,  2 - action: south
# step 49 - position 3 ,  2 - action: suck
# step 50 - position 3 ,  2 - action: north
# step 51 - position 2 ,  2 - action: suck
# step 52 - position 2 ,  2 - action: west
# step 53 - position 2 ,  1 - action: west
# step 54 - position 2 ,  0 - action: east
# step 55 - position 2 ,  1 - action: west
# step 56 - position 2 ,  0 - action: suck
# step 57 - position 2 ,  0 - action: east
# step 58 - position 2 ,  1 - action: east
# step 59 - position 2 ,  2 - action: south
# step 60 - position 3 ,  2 - action: suck
# step 61 - position 3 ,  2 - action: suck
# step 62 - position 3 ,  2 - action: south
# step 63 - position 4 ,  2 - action: east
# step 64 - position 4 ,  3 - action: north
# step 65 - position 3 ,  3 - action: east
# step 66 - position 3 ,  4 - action: east
# step 67 - position 3 ,  4 - action: suck
# step 68 - position 3 ,  4 - action: suck
# step 69 - position 3 ,  4 - action: suck
# step 70 - position 3 ,  4 - action: west
# step 71 - position 3 ,  3 - action: suck
# step 72 - position 3 ,  3 - action: north
# step 73 - position 2 ,  3 - action: suck
# step 74 - position 2 ,  3 - action: suck
# step 75 - position 2 ,  3 - action: south
# step 76 - position 3 ,  3 - action: east
# step 77 - position 3 ,  4 - action: west
# step 78 - position 3 ,  3 - action: suck
# step 79 - position 3 ,  3 - action: suck
# step 80 - position 3 ,  3 - action: north
# step 81 - position 2 ,  3 - action: suck
# step 82 - position 2 ,  3 - action: south
# step 83 - position 3 ,  3 - action: east
# step 84 - position 3 ,  4 - action: east
# step 85 - position 3 ,  4 - action: west
# step 86 - position 3 ,  3 - action: north
# step 87 - position 2 ,  3 - action: north
# step 88 - position 1 ,  3 - action: suck
# step 89 - position 1 ,  3 - action: suck
# step 90 - position 1 ,  3 - action: south
# step 91 - position 2 ,  3 - action: suck
# step 92 - position 2 ,  3 - action: west
# step 93 - position 2 ,  2 - action: north
# step 94 - position 1 ,  2 - action: suck
# step 95 - position 1 ,  2 - action: south
# step 96 - position 2 ,  2 - action: suck
# step 97 - position 2 ,  2 - action: west
# step 98 - position 2 ,  1 - action: south
# step 99 - position 3 ,  1 - action: east
# step 100 - position 3 ,  2 - action: suck
# step 101 - position 3 ,  2 - action: south
# step 102 - position 4 ,  2 - action: suck
# step 103 - position 4 ,  2 - action: south
# step 104 - position 4 ,  2 - action: west
# step 105 - position 4 ,  1 - action: east
# step 106 - position 4 ,  2 - action: west
# step 107 - position 4 ,  1 - action: north
# step 108 - position 3 ,  1 - action: suck
# step 109 - position 3 ,  1 - action: suck
# step 110 - position 3 ,  1 - action: suck
# step 111 - position 3 ,  1 - action: suck
# step 112 - position 3 ,  1 - action: east
# step 113 - position 3 ,  2 - action: suck
# step 114 - position 3 ,  2 - action: west
# step 115 - position 3 ,  1 - action: north
# step 116 - position 2 ,  1 - action: north
# step 117 - position 1 ,  1 - action: south
# step 118 - position 2 ,  1 - action: east
# step 119 - position 2 ,  2 - action: east
# step 120 - position 2 ,  3 - action: north
# step 121 - position 1 ,  3 - action: north
# step 122 - position 0 ,  3 - action: north
# step 123 - position 0 ,  3 - action: south
# step 124 - position 1 ,  3 - action: suck
# step 0 - position 1 ,  4 - action: north
# step 1 - position 0 ,  4 - action: west
# step 2 - position 0 ,  3 - action: suck
# step 3 - position 0 ,  3 - action: east
# step 4 - position 0 ,  4 - action: suck
# step 5 - position 0 ,  4 - action: suck
# step 6 - position 0 ,  4 - action: west
# step 7 - position 0 ,  3 - action: west
# step 8 - position 0 ,  2 - action: west
# step 9 - position 0 ,  1 - action: suck
# step 10 - position 0 ,  1 - action: east
# step 11 - position 0 ,  2 - action: east
# step 12 - position 0 ,  3 - action: east
# step 13 - position 0 ,  4 - action: west
# step 14 - position 0 ,  3 - action: west
# step 15 - position 0 ,  2 - action: west
# step 16 - position 0 ,  1 - action: west
# step 17 - position 0 ,  0 - action: suck
# step 18 - position 0 ,  0 - action: east
# step 19 - position 0 ,  1 - action: east
# step 20 - position 0 ,  2 - action: west
# step 21 - position 0 ,  1 - action: east
# step 22 - position 0 ,  2 - action: east
# step 23 - position 0 ,  3 - action: west
# step 24 - position 0 ,  2 - action: west
# step 25 - position 0 ,  1 - action: east
# step 26 - position 0 ,  2 - action: east
# step 27 - position 0 ,  3 - action: east
# step 28 - position 0 ,  4 - action: west
# step 29 - position 0 ,  3 - action: east
# step 30 - position 0 ,  4 - action: west
# step 31 - position 0 ,  3 - action: east
# step 32 - position 0 ,  4 - action: west
# step 33 - position 0 ,  3 - action: west
# step 34 - position 0 ,  2 - action: west
# step 35 - position 0 ,  1 - action: west
# step 36 - position 0 ,  0 - action: east
# step 37 - position 0 ,  1 - action: suck
# step 38 - position 0 ,  1 - action: east
# step 39 - position 0 ,  2 - action: west
# step 40 - position 0 ,  1 - action: west
# step 41 - position 0 ,  0 - action: east
# step 42 - position 0 ,  1 - action: west
# step 43 - position 0 ,  0 - action: east
# step 44 - position 0 ,  1 - action: west
# step 45 - position 0 ,  0 - action: east
# step 46 - position 0 ,  1 - action: west
# step 47 - position 0 ,  0 - action: east
# step 48 - position 0 ,  1 - action: west
# step 49 - position 0 ,  0 - action: east
# step 50 - position 0 ,  1 - action: west
# step 51 - position 0 ,  0 - action: east
# step 52 - position 0 ,  1 - action: east
# step 53 - position 0 ,  2 - action: west
# step 54 - position 0 ,  1 - action: east
# step 55 - position 0 ,  2 - action: east
# step 56 - position 0 ,  3 - action: suck
# step 57 - position 0 ,  3 - action: west
# step 58 - position 0 ,  2 - action: suck
# step 59 - position 0 ,  2 - action: west
# step 60 - position 0 ,  1 - action: east
# step 61 - position 0 ,  2 - action: east
# step 62 - position 0 ,  3 - action: suck
# step 63 - position 0 ,  3 - action: east
# step 64 - position 0 ,  4 - action: west
# step 65 - position 0 ,  3 - action: east
# step 66 - position 0 ,  4 - action: west
# step 67 - position 0 ,  3 - action: west
# step 68 - position 0 ,  2 - action: west
# step 69 - position 0 ,  1 - action: west
# step 70 - position 0 ,  0 - action: suck
# step 71 - position 0 ,  0 - action: east
# step 72 - position 0 ,  1 - action: east
# step 73 - position 0 ,  2 - action: west
# step 74 - position 0 ,  1 - action: east
# step 75 - position 0 ,  2 - action: east
# step 76 - position 0 ,  3 - action: west
# step 77 - position 0 ,  2 - action: west
# step 78 - position 0 ,  1 - action: west
# step 79 - position 0 ,  0 - action: suck
# step 80 - position 0 ,  0 - action: east
# step 81 - position 0 ,  1 - action: west
# step 82 - position 0 ,  0 - action: east
# step 83 - position 0 ,  1 - action: west
# step 84 - position 0 ,  0 - action: suck
# step 85 - position 0 ,  0 - action: east
# step 86 - position 0 ,  1 - action: west
# step 87 - position 0 ,  0 - action: east
# step 88 - position 0 ,  1 - action: east
# step 89 - position 0 ,  2 - action: west
# step 90 - position 0 ,  1 - action: west
# step 91 - position 0 ,  0 - action: east
# step 92 - position 0 ,  1 - action: west
# step 93 - position 0 ,  0 - action: east
# step 94 - position 0 ,  1 - action: west
# step 95 - position 0 ,  0 - action: east
# step 96 - position 0 ,  1 - action: east
# step 97 - position 0 ,  2 - action: east
# step 98 - position 0 ,  3 - action: west
# step 99 - position 0 ,  2 - action: west
# step 100 - position 0 ,  1 - action: east
# step 101 - position 0 ,  2 - action: west
# step 102 - position 0 ,  1 - action: east
# step 103 - position 0 ,  2 - action: west
# step 104 - position 0 ,  1 - action: east
# step 105 - position 0 ,  2 - action: west
# step 106 - position 0 ,  1 - action: west
# step 107 - position 0 ,  0 - action: east
# step 108 - position 0 ,  1 - action: east
# step 109 - position 0 ,  2 - action: west
# step 110 - position 0 ,  1 - action: west
# step 111 - position 0 ,  0 - action: suck
# step 112 - position 0 ,  0 - action: east
# step 113 - position 0 ,  1 - action: east
# step 114 - position 0 ,  2 - action: west
# step 115 - position 0 ,  1 - action: west
# step 116 - position 0 ,  0 - action: east
# step 117 - position 0 ,  1 - action: west
# step 118 - position 0 ,  0 - action: suck
# step 119 - position 0 ,  0 - action: suck
# step 120 - position 0 ,  0 - action: east
# step 121 - position 0 ,  1 - action: east
# step 122 - position 0 ,  2 - action: west
# step 123 - position 0 ,  1 - action: east
# step 124 - position 0 ,  2 - action: west
# step 0 - position 1 ,  4 - action: north
# step 1 - position 0 ,  4 - action: west
# step 2 - position 0 ,  3 - action: west
# step 3 - position 0 ,  2 - action: suck
# step 4 - position 0 ,  2 - action: west
# step 5 - position 0 ,  1 - action: suck
# step 6 - position 0 ,  1 - action: west
# step 7 - position 0 ,  0 - action: suck
# step 8 - position 0 ,  0 - action: east
# step 9 - position 0 ,  1 - action: east
# step 10 - position 0 ,  2 - action: east
# step 11 - position 0 ,  3 - action: suck
# step 12 - position 0 ,  3 - action: east
# step 13 - position 0 ,  4 - action: suck
# step 14 - position 0 ,  4 - action: suck
# step 15 - position 0 ,  4 - action: suck
# step 16 - position 0 ,  4 - action: suck
# step 17 - position 0 ,  4 - action: suck
# step 18 - position 0 ,  4 - action: suck
# step 19 - position 0 ,  4 - action: suck
# step 20 - position 0 ,  4 - action: suck
# step 21 - position 0 ,  4 - action: suck
# step 22 - position 0 ,  4 - action: suck
# step 23 - position 0 ,  4 - action: suck
# step 24 - position 0 ,  4 - action: suck
# step 25 - position 0 ,  4 - action: suck
# step 26 - position 0 ,  4 - action: suck
# step 27 - position 0 ,  4 - action: suck
# step 28 - position 0 ,  4 - action: suck
# step 29 - position 0 ,  4 - action: suck
# step 30 - position 0 ,  4 - action: suck
# step 31 - position 0 ,  4 - action: suck
# step 32 - position 0 ,  4 - action: suck
# step 33 - position 0 ,  4 - action: suck
# step 34 - position 0 ,  4 - action: suck
# step 35 - position 0 ,  4 - action: suck
# step 36 - position 0 ,  4 - action: suck
# step 37 - position 0 ,  4 - action: suck
# step 38 - position 0 ,  4 - action: suck
# step 39 - position 0 ,  4 - action: suck
# step 40 - position 0 ,  4 - action: suck
# step 41 - position 0 ,  4 - action: suck
# step 42 - position 0 ,  4 - action: suck
# step 43 - position 0 ,  4 - action: suck
# step 44 - position 0 ,  4 - action: suck
# step 45 - position 0 ,  4 - action: suck
# step 46 - position 0 ,  4 - action: suck
# step 47 - position 0 ,  4 - action: suck
# step 48 - position 0 ,  4 - action: suck
# step 49 - position 0 ,  4 - action: suck
# step 50 - position 0 ,  4 - action: suck
# step 51 - position 0 ,  4 - action: suck
# step 52 - position 0 ,  4 - action: suck
# step 53 - position 0 ,  4 - action: suck
# step 54 - position 0 ,  4 - action: suck
# step 55 - position 0 ,  4 - action: suck
# step 56 - position 0 ,  4 - action: suck
# step 57 - position 0 ,  4 - action: suck
# step 58 - position 0 ,  4 - action: suck
# step 59 - position 0 ,  4 - action: suck
# step 60 - position 0 ,  4 - action: suck
# step 61 - position 0 ,  4 - action: suck
# step 62 - position 0 ,  4 - action: suck
# step 63 - position 0 ,  4 - action: suck
# step 64 - position 0 ,  4 - action: suck
# step 65 - position 0 ,  4 - action: suck
# step 66 - position 0 ,  4 - action: suck
# step 67 - position 0 ,  4 - action: suck
# step 68 - position 0 ,  4 - action: suck
# step 69 - position 0 ,  4 - action: suck
# step 70 - position 0 ,  4 - action: suck
# step 71 - position 0 ,  4 - action: suck
# step 72 - position 0 ,  4 - action: suck
# step 73 - position 0 ,  4 - action: suck
# step 74 - position 0 ,  4 - action: suck
# step 75 - position 0 ,  4 - action: suck
# step 76 - position 0 ,  4 - action: suck
# step 77 - position 0 ,  4 - action: suck
# step 78 - position 0 ,  4 - action: suck
# step 79 - position 0 ,  4 - action: suck
# step 80 - position 0 ,  4 - action: suck
# step 81 - position 0 ,  4 - action: suck
# step 82 - position 0 ,  4 - action: suck
# step 83 - position 0 ,  4 - action: suck
# step 84 - position 0 ,  4 - action: suck
# step 85 - position 0 ,  4 - action: suck
# step 86 - position 0 ,  4 - action: suck
# step 87 - position 0 ,  4 - action: suck
# step 88 - position 0 ,  4 - action: suck
# step 89 - position 0 ,  4 - action: suck
# step 90 - position 0 ,  4 - action: suck
# step 91 - position 0 ,  4 - action: suck
# step 92 - position 0 ,  4 - action: suck
# step 93 - position 0 ,  4 - action: suck
# step 94 - position 0 ,  4 - action: suck
# step 95 - position 0 ,  4 - action: suck
# step 96 - position 0 ,  4 - action: suck
# step 97 - position 0 ,  4 - action: suck
# step 98 - position 0 ,  4 - action: suck
# step 99 - position 0 ,  4 - action: suck
# step 100 - position 0 ,  4 - action: suck
# step 101 - position 0 ,  4 - action: suck
# step 102 - position 0 ,  4 - action: suck
# step 103 - position 0 ,  4 - action: suck
# step 104 - position 0 ,  4 - action: suck
# step 105 - position 0 ,  4 - action: suck
# step 106 - position 0 ,  4 - action: suck
# step 107 - position 0 ,  4 - action: suck
# step 108 - position 0 ,  4 - action: suck
# step 109 - position 0 ,  4 - action: suck
# step 110 - position 0 ,  4 - action: suck
# step 111 - position 0 ,  4 - action: suck
# step 112 - position 0 ,  4 - action: suck
# step 113 - position 0 ,  4 - action: suck
# step 114 - position 0 ,  4 - action: suck
# step 115 - position 0 ,  4 - action: suck
# step 116 - position 0 ,  4 - action: suck
# step 117 - position 0 ,  4 - action: suck
# step 118 - position 0 ,  4 - action: suck
# step 119 - position 0 ,  4 - action: suck
# step 120 - position 0 ,  4 - action: suck
# step 121 - position 0 ,  4 - action: suck
# step 122 - position 0 ,  4 - action: suck
# step 123 - position 0 ,  4 - action: suck
# step 124 - position 0 ,  4 - action: suck
# step 0 - position 0 ,  2 - action: east
# step 1 - position 0 ,  3 - action: west
# step 2 - position 0 ,  2 - action: south
# step 3 - position 1 ,  2 - action: east
# step 4 - position 1 ,  3 - action: north
# step 5 - position 0 ,  3 - action: east
# step 6 - position 0 ,  4 - action: south
# step 7 - position 1 ,  4 - action: suck
# step 8 - position 1 ,  4 - action: suck
# step 9 - position 1 ,  4 - action: south
# step 10 - position 2 ,  4 - action: north
# step 11 - position 1 ,  4 - action: suck
# step 12 - position 1 ,  4 - action: west
# step 13 - position 1 ,  3 - action: south
# step 14 - position 2 ,  3 - action: north
# step 15 - position 1 ,  3 - action: east
# step 16 - position 1 ,  4 - action: north
# step 17 - position 0 ,  4 - action: suck
# step 18 - position 0 ,  4 - action: west
# step 19 - position 0 ,  3 - action: north
# step 20 - position 0 ,  3 - action: west
# step 21 - position 0 ,  2 - action: east
# step 22 - position 0 ,  3 - action: south
# step 23 - position 1 ,  3 - action: north
# step 24 - position 0 ,  3 - action: north
# step 25 - position 0 ,  3 - action: suck
# step 26 - position 0 ,  3 - action: south
# step 27 - position 1 ,  3 - action: north
# step 28 - position 0 ,  3 - action: south
# step 29 - position 1 ,  3 - action: south
# step 30 - position 2 ,  3 - action: east
# step 31 - position 2 ,  4 - action: north
# step 32 - position 1 ,  4 - action: suck
# step 33 - position 1 ,  4 - action: north
# step 34 - position 0 ,  4 - action: suck
# step 35 - position 0 ,  4 - action: south
# step 36 - position 1 ,  4 - action: north
# step 37 - position 0 ,  4 - action: south
# step 38 - position 1 ,  4 - action: suck
# step 39 - position 1 ,  4 - action: west
# step 40 - position 1 ,  3 - action: east
# step 41 - position 1 ,  4 - action: suck
# step 42 - position 1 ,  4 - action: west
# step 43 - position 1 ,  3 - action: west
# step 44 - position 1 ,  2 - action: south
# step 45 - position 2 ,  2 - action: east
# step 46 - position 2 ,  3 - action: south
# step 47 - position 3 ,  3 - action: suck
# step 48 - position 3 ,  3 - action: west
# step 49 - position 3 ,  2 - action: suck
# step 50 - position 3 ,  2 - action: north
# step 51 - position 2 ,  2 - action: south
# step 52 - position 3 ,  2 - action: suck
# step 53 - position 3 ,  2 - action: west
# step 54 - position 3 ,  1 - action: suck
# step 55 - position 3 ,  1 - action: north
# step 56 - position 2 ,  1 - action: north
# step 57 - position 1 ,  1 - action: east
# step 58 - position 1 ,  2 - action: east
# step 59 - position 1 ,  3 - action: west
# step 60 - position 1 ,  2 - action: north
# step 61 - position 0 ,  2 - action: north
# step 62 - position 0 ,  2 - action: north
# step 63 - position 0 ,  2 - action: south
# step 64 - position 1 ,  2 - action: west
# step 65 - position 1 ,  1 - action: west
# step 66 - position 1 ,  0 - action: west
# step 67 - position 1 ,  0 - action: east
# step 68 - position 1 ,  1 - action: east
# step 69 - position 1 ,  2 - action: west
# step 70 - position 1 ,  1 - action: north
# step 71 - position 0 ,  1 - action: north
# step 72 - position 0 ,  1 - action: suck
# step 73 - position 0 ,  1 - action: suck
# step 74 - position 0 ,  1 - action: suck
# step 75 - position 0 ,  1 - action: south
# step 76 - position 1 ,  1 - action: south
# step 77 - position 2 ,  1 - action: north
# step 78 - position 1 ,  1 - action: east
# step 79 - position 1 ,  2 - action: east
# step 80 - position 1 ,  3 - action: south
# step 81 - position 2 ,  3 - action: south
# step 82 - position 3 ,  3 - action: north
# step 83 - position 2 ,  3 - action: east
# step 84 - position 2 ,  4 - action: west
# step 85 - position 2 ,  3 - action: south
# step 86 - position 3 ,  3 - action: east
# step 87 - position 3 ,  4 - action: north
# step 88 - position 2 ,  4 - action: east
# step 89 - position 2 ,  5 - action: north
# step 90 - position 1 ,  5 - action: east
# step 91 - position 1 ,  6 - action: suck
# step 92 - position 1 ,  6 - action: east
# step 93 - position 1 ,  7 - action: west
# step 94 - position 1 ,  6 - action: south
# step 95 - position 2 ,  6 - action: east
# step 96 - position 2 ,  7 - action: east
# step 97 - position 2 ,  8 - action: east
# step 98 - position 2 ,  9 - action: suck
# step 99 - position 2 ,  9 - action: south
# step 100 - position 3 ,  9 - action: east
# step 101 - position 3 ,  9 - action: west
# step 102 - position 3 ,  8 - action: east
# step 103 - position 3 ,  9 - action: south
# step 104 - position 4 ,  9 - action: west
# step 105 - position 4 ,  8 - action: suck
# step 106 - position 4 ,  8 - action: east
# step 107 - position 4 ,  9 - action: east
# step 108 - position 4 ,  9 - action: east
# step 109 - position 4 ,  9 - action: east
# step 110 - position 4 ,  9 - action: suck
# step 111 - position 4 ,  9 - action: suck
# step 112 - position 4 ,  9 - action: east
# step 113 - position 4 ,  9 - action: suck
# step 114 - position 4 ,  9 - action: west
# step 115 - position 4 ,  8 - action: east
# step 116 - position 4 ,  9 - action: suck
# step 117 - position 4 ,  9 - action: south
# step 118 - position 5 ,  9 - action: south
# step 119 - position 6 ,  9 - action: east
# step 120 - position 6 ,  9 - action: north
# step 121 - position 5 ,  9 - action: west
# step 122 - position 5 ,  8 - action: west
# step 123 - position 5 ,  7 - action: east
# step 124 - position 5 ,  8 - action: west
# step 125 - position 5 ,  7 - action: east
# step 126 - position 5 ,  8 - action: west
# step 127 - position 5 ,  7 - action: east
# step 128 - position 5 ,  8 - action: south
# step 129 - position 6 ,  8 - action: west
# step 130 - position 6 ,  7 - action: north
# step 131 - position 5 ,  7 - action: east
# step 132 - position 5 ,  8 - action: suck
# step 133 - position 5 ,  8 - action: suck
# step 134 - position 5 ,  8 - action: west
# step 135 - position 5 ,  7 - action: north
# step 136 - position 4 ,  7 - action: north
# step 137 - position 3 ,  7 - action: west
# step 138 - position 3 ,  6 - action: north
# step 139 - position 2 ,  6 - action: east
# step 140 - position 2 ,  7 - action: suck
# step 141 - position 2 ,  7 - action: south
# step 142 - position 3 ,  7 - action: east
# step 143 - position 3 ,  8 - action: east
# step 144 - position 3 ,  9 - action: west
# step 145 - position 3 ,  8 - action: south
# step 146 - position 4 ,  8 - action: east
# step 147 - position 4 ,  9 - action: north
# step 148 - position 3 ,  9 - action: west
# step 149 - position 3 ,  8 - action: suck
# step 150 - position 3 ,  8 - action: east
# step 151 - position 3 ,  9 - action: east
# step 152 - position 3 ,  9 - action: south
# step 153 - position 4 ,  9 - action: west
# step 154 - position 4 ,  8 - action: east
# step 155 - position 4 ,  9 - action: south
# step 156 - position 5 ,  9 - action: east
# step 157 - position 5 ,  9 - action: north
# step 158 - position 4 ,  9 - action: east
# step 159 - position 4 ,  9 - action: west
# step 160 - position 4 ,  8 - action: south
# step 161 - position 5 ,  8 - action: west
# step 162 - position 5 ,  7 - action: west
# step 163 - position 5 ,  6 - action: west
# step 164 - position 5 ,  5 - action: west
# step 165 - position 5 ,  4 - action: west
# step 166 - position 5 ,  3 - action: west
# step 167 - position 5 ,  2 - action: west
# step 168 - position 5 ,  1 - action: north
# step 169 - position 4 ,  1 - action: east
# step 170 - position 4 ,  2 - action: east
# step 171 - position 4 ,  3 - action: suck
# step 172 - position 4 ,  3 - action: west
# step 173 - position 4 ,  2 - action: south
# step 174 - position 5 ,  2 - action: east
# step 175 - position 5 ,  3 - action: north
# step 176 - position 4 ,  3 - action: east
# step 177 - position 4 ,  4 - action: west
# step 178 - position 4 ,  3 - action: west
# step 179 - position 4 ,  2 - action: south
# step 180 - position 5 ,  2 - action: north
# step 181 - position 4 ,  2 - action: suck
# step 182 - position 4 ,  2 - action: suck
# step 183 - position 4 ,  2 - action: south
# step 184 - position 5 ,  2 - action: south
# step 185 - position 6 ,  2 - action: south
# step 186 - position 7 ,  2 - action: east
# step 187 - position 7 ,  3 - action: south
# step 188 - position 8 ,  3 - action: suck
# step 189 - position 8 ,  3 - action: suck
# step 190 - position 8 ,  3 - action: east
# step 191 - position 8 ,  4 - action: west
# step 192 - position 8 ,  3 - action: south
# step 193 - position 9 ,  3 - action: west
# step 194 - position 9 ,  2 - action: south
# step 195 - position 9 ,  2 - action: east
# step 196 - position 9 ,  3 - action: suck
# step 197 - position 9 ,  3 - action: suck
# step 198 - position 9 ,  3 - action: east
# step 199 - position 9 ,  4 - action: north
# step 200 - position 8 ,  4 - action: south
# step 201 - position 9 ,  4 - action: east
# step 202 - position 9 ,  5 - action: west
# step 203 - position 9 ,  4 - action: north
# step 204 - position 8 ,  4 - action: north
# step 205 - position 7 ,  4 - action: east
# step 206 - position 7 ,  5 - action: east
# step 207 - position 7 ,  6 - action: north
# step 208 - position 6 ,  6 - action: suck
# step 209 - position 6 ,  6 - action: suck
# step 210 - position 6 ,  6 - action: suck
# step 211 - position 6 ,  6 - action: west
# step 212 - position 6 ,  5 - action: east
# step 213 - position 6 ,  6 - action: north
# step 214 - position 5 ,  6 - action: west
# step 215 - position 5 ,  5 - action: suck
# step 216 - position 5 ,  5 - action: suck
# step 217 - position 5 ,  5 - action: east
# step 218 - position 5 ,  6 - action: south
# step 219 - position 6 ,  6 - action: west
# step 220 - position 6 ,  5 - action: east
# step 221 - position 6 ,  6 - action: north
# step 222 - position 5 ,  6 - action: suck
# step 223 - position 5 ,  6 - action: west
# step 224 - position 5 ,  5 - action: south
# step 225 - position 6 ,  5 - action: suck
# step 226 - position 6 ,  5 - action: east
# step 227 - position 6 ,  6 - action: west
# step 228 - position 6 ,  5 - action: east
# step 229 - position 6 ,  6 - action: east
# step 230 - position 6 ,  7 - action: west
# step 231 - position 6 ,  6 - action: suck
# step 232 - position 6 ,  6 - action: north
# step 233 - position 5 ,  6 - action: suck
# step 234 - position 5 ,  6 - action: north
# step 235 - position 4 ,  6 - action: north
# step 236 - position 3 ,  6 - action: east
# step 237 - position 3 ,  7 - action: south
# step 238 - position 4 ,  7 - action: suck
# step 239 - position 4 ,  7 - action: suck
# step 240 - position 4 ,  7 - action: south
# step 241 - position 5 ,  7 - action: north
# step 242 - position 4 ,  7 - action: west
# step 243 - position 4 ,  6 - action: east
# step 244 - position 4 ,  7 - action: west
# step 245 - position 4 ,  6 - action: east
# step 246 - position 4 ,  7 - action: north
# step 247 - position 3 ,  7 - action: east
# step 248 - position 3 ,  8 - action: east
# step 249 - position 3 ,  9 - action: north
# step 250 - position 2 ,  9 - action: west
# step 251 - position 2 ,  8 - action: west
# step 252 - position 2 ,  7 - action: west
# step 253 - position 2 ,  6 - action: north
# step 254 - position 1 ,  6 - action: west
# step 255 - position 1 ,  5 - action: west
# step 256 - position 1 ,  4 - action: south
# step 257 - position 2 ,  4 - action: west
# step 258 - position 2 ,  3 - action: north
# step 259 - position 1 ,  3 - action: south
# step 260 - position 2 ,  3 - action: south
# step 261 - position 3 ,  3 - action: south
# step 262 - position 4 ,  3 - action: suck
# step 263 - position 4 ,  3 - action: west
# step 264 - position 4 ,  2 - action: south
# step 265 - position 5 ,  2 - action: north
# step 266 - position 4 ,  2 - action: south
# step 267 - position 5 ,  2 - action: suck
# step 268 - position 5 ,  2 - action: suck
# step 269 - position 5 ,  2 - action: suck
# step 270 - position 5 ,  2 - action: suck
# step 271 - position 5 ,  2 - action: south
# step 272 - position 6 ,  2 - action: east
# step 273 - position 6 ,  3 - action: west
# step 274 - position 6 ,  2 - action: west
# step 275 - position 6 ,  1 - action: east
# step 276 - position 6 ,  2 - action: suck
# step 277 - position 6 ,  2 - action: east
# step 278 - position 6 ,  3 - action: north
# step 279 - position 5 ,  3 - action: suck
# step 280 - position 5 ,  3 - action: west
# step 281 - position 5 ,  2 - action: north
# step 282 - position 4 ,  2 - action: north
# step 283 - position 3 ,  2 - action: south
# step 284 - position 4 ,  2 - action: east
# step 285 - position 4 ,  3 - action: west
# step 286 - position 4 ,  2 - action: suck
# step 287 - position 4 ,  2 - action: east
# step 288 - position 4 ,  3 - action: west
# step 289 - position 4 ,  2 - action: north
# step 290 - position 3 ,  2 - action: north
# step 291 - position 2 ,  2 - action: north
# step 292 - position 1 ,  2 - action: north
# step 293 - position 0 ,  2 - action: east
# step 294 - position 0 ,  3 - action: south
# step 295 - position 1 ,  3 - action: north
# step 296 - position 0 ,  3 - action: suck
# step 297 - position 0 ,  3 - action: north
# step 298 - position 0 ,  3 - action: west
# step 299 - position 0 ,  2 - action: suck
# step 300 - position 0 ,  2 - action: east
# step 301 - position 0 ,  3 - action: suck
# step 302 - position 0 ,  3 - action: east
# step 303 - position 0 ,  4 - action: north
# step 304 - position 0 ,  4 - action: north
# step 305 - position 0 ,  4 - action: north
# step 306 - position 0 ,  4 - action: north
# step 307 - position 0 ,  4 - action: suck
# step 308 - position 0 ,  4 - action: north
# step 309 - position 0 ,  4 - action: north
# step 310 - position 0 ,  4 - action: west
# step 311 - position 0 ,  3 - action: south
# step 312 - position 1 ,  3 - action: suck
# step 313 - position 1 ,  3 - action: north
# step 314 - position 0 ,  3 - action: suck
# step 315 - position 0 ,  3 - action: east
# step 316 - position 0 ,  4 - action: west
# step 317 - position 0 ,  3 - action: west
# step 318 - position 0 ,  2 - action: suck
# step 319 - position 0 ,  2 - action: east
# step 320 - position 0 ,  3 - action: east
# step 321 - position 0 ,  4 - action: south
# step 322 - position 1 ,  4 - action: east
# step 323 - position 1 ,  5 - action: north
# step 324 - position 0 ,  5 - action: south
# step 325 - position 1 ,  5 - action: south
# step 326 - position 2 ,  5 - action: west
# step 327 - position 2 ,  4 - action: north
# step 328 - position 1 ,  4 - action: north
# step 329 - position 0 ,  4 - action: suck
# step 330 - position 0 ,  4 - action: east
# step 331 - position 0 ,  5 - action: east
# step 332 - position 0 ,  6 - action: west
# step 333 - position 0 ,  5 - action: west
# step 334 - position 0 ,  4 - action: north
# step 335 - position 0 ,  4 - action: west
# step 336 - position 0 ,  3 - action: north
# step 337 - position 0 ,  3 - action: west
# step 338 - position 0 ,  2 - action: north
# step 339 - position 0 ,  2 - action: south
# step 340 - position 1 ,  2 - action: west
# step 341 - position 1 ,  1 - action: west
# step 342 - position 1 ,  0 - action: east
# step 343 - position 1 ,  1 - action: west
# step 344 - position 1 ,  0 - action: south
# step 345 - position 2 ,  0 - action: south
# step 346 - position 3 ,  0 - action: north
# step 347 - position 2 ,  0 - action: north
# step 348 - position 1 ,  0 - action: north
# step 349 - position 0 ,  0 - action: suck
# step 350 - position 0 ,  0 - action: suck
# step 351 - position 0 ,  0 - action: south
# step 352 - position 1 ,  0 - action: north
# step 353 - position 0 ,  0 - action: east
# step 354 - position 0 ,  1 - action: west
# step 355 - position 0 ,  0 - action: north
# step 356 - position 0 ,  0 - action: north
# step 357 - position 0 ,  0 - action: north
# step 358 - position 0 ,  0 - action: west
# step 359 - position 0 ,  0 - action: south
# step 360 - position 1 ,  0 - action: east
# step 361 - position 1 ,  1 - action: suck
# step 362 - position 1 ,  1 - action: south
# step 363 - position 2 ,  1 - action: east
# step 364 - position 2 ,  2 - action: south
# step 365 - position 3 ,  2 - action: suck
# step 366 - position 3 ,  2 - action: east
# step 367 - position 3 ,  3 - action: suck
# step 368 - position 3 ,  3 - action: suck
# step 369 - position 3 ,  3 - action: north
# step 370 - position 2 ,  3 - action: south
# step 371 - position 3 ,  3 - action: suck
# step 372 - position 3 ,  3 - action: west
# step 373 - position 3 ,  2 - action: south
# step 374 - position 4 ,  2 - action: east
# step 375 - position 4 ,  3 - action: west
# step 376 - position 4 ,  2 - action: east
# step 377 - position 4 ,  3 - action: west
# step 378 - position 4 ,  2 - action: north
# step 379 - position 3 ,  2 - action: south
# step 380 - position 4 ,  2 - action: west
# step 381 - position 4 ,  1 - action: north
# step 382 - position 3 ,  1 - action: east
# step 383 - position 3 ,  2 - action: east
# step 384 - position 3 ,  3 - action: east
# step 385 - position 3 ,  4 - action: west
# step 386 - position 3 ,  3 - action: west
# step 387 - position 3 ,  2 - action: east
# step 388 - position 3 ,  3 - action: suck
# step 389 - position 3 ,  3 - action: north
# step 390 - position 2 ,  3 - action: north
# step 391 - position 1 ,  3 - action: south
# step 392 - position 2 ,  3 - action: north
# step 393 - position 1 ,  3 - action: south
# step 394 - position 2 ,  3 - action: east
# step 395 - position 2 ,  4 - action: south
# step 396 - position 3 ,  4 - action: south
# step 397 - position 4 ,  4 - action: suck
# step 398 - position 4 ,  4 - action: west
# step 399 - position 4 ,  3 - action: west
# step 400 - position 4 ,  2 - action: suck
# step 401 - position 4 ,  2 - action: north
# step 402 - position 3 ,  2 - action: suck
# step 403 - position 3 ,  2 - action: west
# step 404 - position 3 ,  1 - action: north
# step 405 - position 2 ,  1 - action: suck
# step 406 - position 2 ,  1 - action: north
# step 407 - position 1 ,  1 - action: north
# step 408 - position 0 ,  1 - action: south
# step 409 - position 1 ,  1 - action: west
# step 410 - position 1 ,  0 - action: suck
# step 411 - position 1 ,  0 - action: north
# step 412 - position 0 ,  0 - action: west
# step 413 - position 0 ,  0 - action: east
# step 414 - position 0 ,  1 - action: west
# step 415 - position 0 ,  0 - action: suck
# step 416 - position 0 ,  0 - action: east
# step 417 - position 0 ,  1 - action: north
# step 418 - position 0 ,  1 - action: suck
# step 419 - position 0 ,  1 - action: south
# step 420 - position 1 ,  1 - action: south
# step 421 - position 2 ,  1 - action: suck
# step 422 - position 2 ,  1 - action: suck
# step 423 - position 2 ,  1 - action: north
# step 424 - position 1 ,  1 - action: west
# step 425 - position 1 ,  0 - action: east
# step 426 - position 1 ,  1 - action: west
# step 427 - position 1 ,  0 - action: south
# step 428 - position 2 ,  0 - action: north
# step 429 - position 1 ,  0 - action: suck
# step 430 - position 1 ,  0 - action: south
# step 431 - position 2 ,  0 - action: north
# step 432 - position 1 ,  0 - action: suck
# step 433 - position 1 ,  0 - action: east
# step 434 - position 1 ,  1 - action: north
# step 435 - position 0 ,  1 - action: south
# step 436 - position 1 ,  1 - action: suck
# step 437 - position 1 ,  1 - action: north
# step 438 - position 0 ,  1 - action: west
# step 439 - position 0 ,  0 - action: suck
# step 440 - position 0 ,  0 - action: north
# step 441 - position 0 ,  0 - action: suck
# step 442 - position 0 ,  0 - action: suck
# step 443 - position 0 ,  0 - action: north
# step 444 - position 0 ,  0 - action: west
# step 445 - position 0 ,  0 - action: south
# step 446 - position 1 ,  0 - action: north
# step 447 - position 0 ,  0 - action: east
# step 448 - position 0 ,  1 - action: suck
# step 449 - position 0 ,  1 - action: north
# step 450 - position 0 ,  1 - action: west
# step 451 - position 0 ,  0 - action: south
# step 452 - position 1 ,  0 - action: south
# step 453 - position 2 ,  0 - action: west
# step 454 - position 2 ,  0 - action: west
# step 455 - position 2 ,  0 - action: north
# step 456 - position 1 ,  0 - action: suck
# step 457 - position 1 ,  0 - action: west
# step 458 - position 1 ,  0 - action: south
# step 459 - position 2 ,  0 - action: north
# step 460 - position 1 ,  0 - action: east
# step 461 - position 1 ,  1 - action: north
# step 462 - position 0 ,  1 - action: west
# step 463 - position 0 ,  0 - action: suck
# step 464 - position 0 ,  0 - action: west
# step 465 - position 0 ,  0 - action: east
# step 466 - position 0 ,  1 - action: suck
# step 467 - position 0 ,  1 - action: east
# step 468 - position 0 ,  2 - action: north
# step 469 - position 0 ,  2 - action: west
# step 470 - position 0 ,  1 - action: north
# step 471 - position 0 ,  1 - action: north
# step 472 - position 0 ,  1 - action: north
# step 473 - position 0 ,  1 - action: suck
# step 474 - position 0 ,  1 - action: east
# step 475 - position 0 ,  2 - action: east
# step 476 - position 0 ,  3 - action: west
# step 477 - position 0 ,  2 - action: east
# step 478 - position 0 ,  3 - action: south
# step 479 - position 1 ,  3 - action: south
# step 480 - position 2 ,  3 - action: east
# step 481 - position 2 ,  4 - action: south
# step 482 - position 3 ,  4 - action: east
# step 483 - position 3 ,  5 - action: south
# step 484 - position 4 ,  5 - action: north
# step 485 - position 3 ,  5 - action: south
# step 486 - position 4 ,  5 - action: south
# step 487 - position 5 ,  5 - action: west
# step 488 - position 5 ,  4 - action: west
# step 489 - position 5 ,  3 - action: east
# step 490 - position 5 ,  4 - action: north
# step 491 - position 4 ,  4 - action: north
# step 492 - position 3 ,  4 - action: south
# step 493 - position 4 ,  4 - action: suck
# step 494 - position 4 ,  4 - action: south
# step 495 - position 5 ,  4 - action: suck
# step 496 - position 5 ,  4 - action: suck
# step 497 - position 5 ,  4 - action: east
# step 498 - position 5 ,  5 - action: suck
# step 499 - position 5 ,  5 - action: north
# step 0 - position 0 ,  2 - action: suck
# step 1 - position 0 ,  2 - action: east
# step 2 - position 0 ,  3 - action: suck
# step 3 - position 0 ,  3 - action: west
# step 4 - position 0 ,  2 - action: west
# step 5 - position 0 ,  1 - action: west
# step 6 - position 0 ,  0 - action: suck
# step 7 - position 0 ,  0 - action: east
# step 8 - position 0 ,  1 - action: west
# step 9 - position 0 ,  0 - action: east
# step 10 - position 0 ,  1 - action: west
# step 11 - position 0 ,  0 - action: east
# step 12 - position 0 ,  1 - action: east
# step 13 - position 0 ,  2 - action: east
# step 14 - position 0 ,  3 - action: west
# step 15 - position 0 ,  2 - action: east
# step 16 - position 0 ,  3 - action: west
# step 17 - position 0 ,  2 - action: west
# step 18 - position 0 ,  1 - action: east
# step 19 - position 0 ,  2 - action: west
# step 20 - position 0 ,  1 - action: east
# step 21 - position 0 ,  2 - action: west
# step 22 - position 0 ,  1 - action: east
# step 23 - position 0 ,  2 - action: east
# step 24 - position 0 ,  3 - action: west
# step 25 - position 0 ,  2 - action: east
# step 26 - position 0 ,  3 - action: east
# step 27 - position 0 ,  4 - action: east
# step 28 - position 0 ,  5 - action: east
# step 29 - position 0 ,  6 - action: west
# step 30 - position 0 ,  5 - action: east
# step 31 - position 0 ,  6 - action: west
# step 32 - position 0 ,  5 - action: west
# step 33 - position 0 ,  4 - action: east
# step 34 - position 0 ,  5 - action: west
# step 35 - position 0 ,  4 - action: east
# step 36 - position 0 ,  5 - action: east
# step 37 - position 0 ,  6 - action: east
# step 38 - position 0 ,  7 - action: west
# step 39 - position 0 ,  6 - action: west
# step 40 - position 0 ,  5 - action: west
# step 41 - position 0 ,  4 - action: east
# step 42 - position 0 ,  5 - action: west
# step 43 - position 0 ,  4 - action: west
# step 44 - position 0 ,  3 - action: east
# step 45 - position 0 ,  4 - action: east
# step 46 - position 0 ,  5 - action: west
# step 47 - position 0 ,  4 - action: west
# step 48 - position 0 ,  3 - action: east
# step 49 - position 0 ,  4 - action: west
# step 50 - position 0 ,  3 - action: east
# step 51 - position 0 ,  4 - action: east
# step 52 - position 0 ,  5 - action: east
# step 53 - position 0 ,  6 - action: east
# step 54 - position 0 ,  7 - action: east
# step 55 - position 0 ,  8 - action: east
# step 56 - position 0 ,  9 - action: suck
# step 57 - position 0 ,  9 - action: west
# step 58 - position 0 ,  8 - action: west
# step 59 - position 0 ,  7 - action: east
# step 60 - position 0 ,  8 - action: east
# step 61 - position 0 ,  9 - action: suck
# step 62 - position 0 ,  9 - action: west
# step 63 - position 0 ,  8 - action: east
# step 64 - position 0 ,  9 - action: west
# step 65 - position 0 ,  8 - action: west
# step 66 - position 0 ,  7 - action: west
# step 67 - position 0 ,  6 - action: east
# step 68 - position 0 ,  7 - action: east
# step 69 - position 0 ,  8 - action: east
# step 70 - position 0 ,  9 - action: suck
# step 71 - position 0 ,  9 - action: west
# step 72 - position 0 ,  8 - action: suck
# step 73 - position 0 ,  8 - action: west
# step 74 - position 0 ,  7 - action: west
# step 75 - position 0 ,  6 - action: west
# step 76 - position 0 ,  5 - action: west
# step 77 - position 0 ,  4 - action: west
# step 78 - position 0 ,  3 - action: east
# step 79 - position 0 ,  4 - action: east
# step 80 - position 0 ,  5 - action: west
# step 81 - position 0 ,  4 - action: east
# step 82 - position 0 ,  5 - action: west
# step 83 - position 0 ,  4 - action: east
# step 84 - position 0 ,  5 - action: east
# step 85 - position 0 ,  6 - action: east
# step 86 - position 0 ,  7 - action: east
# step 87 - position 0 ,  8 - action: west
# step 88 - position 0 ,  7 - action: east
# step 89 - position 0 ,  8 - action: west
# step 90 - position 0 ,  7 - action: east
# step 91 - position 0 ,  8 - action: west
# step 92 - position 0 ,  7 - action: west
# step 93 - position 0 ,  6 - action: west
# step 94 - position 0 ,  5 - action: east
# step 95 - position 0 ,  6 - action: east
# step 96 - position 0 ,  7 - action: east
# step 97 - position 0 ,  8 - action: west
# step 98 - position 0 ,  7 - action: east
# step 99 - position 0 ,  8 - action: east
# step 100 - position 0 ,  9 - action: west
# step 101 - position 0 ,  8 - action: west
# step 102 - position 0 ,  7 - action: east
# step 103 - position 0 ,  8 - action: west
# step 104 - position 0 ,  7 - action: west
# step 105 - position 0 ,  6 - action: west
# step 106 - position 0 ,  5 - action: west
# step 107 - position 0 ,  4 - action: west
# step 108 - position 0 ,  3 - action: east
# step 109 - position 0 ,  4 - action: west
# step 110 - position 0 ,  3 - action: east
# step 111 - position 0 ,  4 - action: east
# step 112 - position 0 ,  5 - action: west
# step 113 - position 0 ,  4 - action: west
# step 114 - position 0 ,  3 - action: east
# step 115 - position 0 ,  4 - action: east
# step 116 - position 0 ,  5 - action: west
# step 117 - position 0 ,  4 - action: east
# step 118 - position 0 ,  5 - action: east
# step 119 - position 0 ,  6 - action: east
# step 120 - position 0 ,  7 - action: west
# step 121 - position 0 ,  6 - action: west
# step 122 - position 0 ,  5 - action: west
# step 123 - position 0 ,  4 - action: west
# step 124 - position 0 ,  3 - action: east
# step 125 - position 0 ,  4 - action: west
# step 126 - position 0 ,  3 - action: west
# step 127 - position 0 ,  2 - action: west
# step 128 - position 0 ,  1 - action: west
# step 129 - position 0 ,  0 - action: east
# step 130 - position 0 ,  1 - action: suck
# step 131 - position 0 ,  1 - action: east
# step 132 - position 0 ,  2 - action: east
# step 133 - position 0 ,  3 - action: west
# step 134 - position 0 ,  2 - action: east
# step 135 - position 0 ,  3 - action: west
# step 136 - position 0 ,  2 - action: east
# step 137 - position 0 ,  3 - action: west
# step 138 - position 0 ,  2 - action: west
# step 139 - position 0 ,  1 - action: east
# step 140 - position 0 ,  2 - action: east
# step 141 - position 0 ,  3 - action: west
# step 142 - position 0 ,  2 - action: west
# step 143 - position 0 ,  1 - action: west
# step 144 - position 0 ,  0 - action: east
# step 145 - position 0 ,  1 - action: east
# step 146 - position 0 ,  2 - action: suck
# step 147 - position 0 ,  2 - action: west
# step 148 - position 0 ,  1 - action: west
# step 149 - position 0 ,  0 - action: east
# step 150 - position 0 ,  1 - action: west
# step 151 - position 0 ,  0 - action: east
# step 152 - position 0 ,  1 - action: suck
# step 153 - position 0 ,  1 - action: suck
# step 154 - position 0 ,  1 - action: west
# step 155 - position 0 ,  0 - action: east
# step 156 - position 0 ,  1 - action: west
# step 157 - position 0 ,  0 - action: suck
# step 158 - position 0 ,  0 - action: suck
# step 159 - position 0 ,  0 - action: east
# step 160 - position 0 ,  1 - action: west
# step 161 - position 0 ,  0 - action: suck
# step 162 - position 0 ,  0 - action: suck
# step 163 - position 0 ,  0 - action: east
# step 164 - position 0 ,  1 - action: east
# step 165 - position 0 ,  2 - action: west
# step 166 - position 0 ,  1 - action: east
# step 167 - position 0 ,  2 - action: east
# step 168 - position 0 ,  3 - action: east
# step 169 - position 0 ,  4 - action: east
# step 170 - position 0 ,  5 - action: west
# step 171 - position 0 ,  4 - action: east
# step 172 - position 0 ,  5 - action: east
# step 173 - position 0 ,  6 - action: east
# step 174 - position 0 ,  7 - action: west
# step 175 - position 0 ,  6 - action: west
# step 176 - position 0 ,  5 - action: east
# step 177 - position 0 ,  6 - action: east
# step 178 - position 0 ,  7 - action: west
# step 179 - position 0 ,  6 - action: west
# step 180 - position 0 ,  5 - action: west
# step 181 - position 0 ,  4 - action: west
# step 182 - position 0 ,  3 - action: west
# step 183 - position 0 ,  2 - action: east
# step 184 - position 0 ,  3 - action: west
# step 185 - position 0 ,  2 - action: east
# step 186 - position 0 ,  3 - action: west
# step 187 - position 0 ,  2 - action: east
# step 188 - position 0 ,  3 - action: west
# step 189 - position 0 ,  2 - action: east
# step 190 - position 0 ,  3 - action: east
# step 191 - position 0 ,  4 - action: east
# step 192 - position 0 ,  5 - action: west
# step 193 - position 0 ,  4 - action: west
# step 194 - position 0 ,  3 - action: east
# step 195 - position 0 ,  4 - action: east
# step 196 - position 0 ,  5 - action: west
# step 197 - position 0 ,  4 - action: east
# step 198 - position 0 ,  5 - action: west
# step 199 - position 0 ,  4 - action: east
# step 200 - position 0 ,  5 - action: west
# step 201 - position 0 ,  4 - action: east
# step 202 - position 0 ,  5 - action: east
# step 203 - position 0 ,  6 - action: west
# step 204 - position 0 ,  5 - action: east
# step 205 - position 0 ,  6 - action: west
# step 206 - position 0 ,  5 - action: west
# step 207 - position 0 ,  4 - action: east
# step 208 - position 0 ,  5 - action: west
# step 209 - position 0 ,  4 - action: west
# step 210 - position 0 ,  3 - action: east
# step 211 - position 0 ,  4 - action: east
# step 212 - position 0 ,  5 - action: west
# step 213 - position 0 ,  4 - action: east
# step 214 - position 0 ,  5 - action: east
# step 215 - position 0 ,  6 - action: west
# step 216 - position 0 ,  5 - action: east
# step 217 - position 0 ,  6 - action: east
# step 218 - position 0 ,  7 - action: east
# step 219 - position 0 ,  8 - action: suck
# step 220 - position 0 ,  8 - action: west
# step 221 - position 0 ,  7 - action: east
# step 222 - position 0 ,  8 - action: west
# step 223 - position 0 ,  7 - action: east
# step 224 - position 0 ,  8 - action: west
# step 225 - position 0 ,  7 - action: west
# step 226 - position 0 ,  6 - action: east
# step 227 - position 0 ,  7 - action: west
# step 228 - position 0 ,  6 - action: west
# step 229 - position 0 ,  5 - action: east
# step 230 - position 0 ,  6 - action: west
# step 231 - position 0 ,  5 - action: east
# step 232 - position 0 ,  6 - action: west
# step 233 - position 0 ,  5 - action: west
# step 234 - position 0 ,  4 - action: west
# step 235 - position 0 ,  3 - action: east
# step 236 - position 0 ,  4 - action: west
# step 237 - position 0 ,  3 - action: east
# step 238 - position 0 ,  4 - action: east
# step 239 - position 0 ,  5 - action: east
# step 240 - position 0 ,  6 - action: east
# step 241 - position 0 ,  7 - action: west
# step 242 - position 0 ,  6 - action: east
# step 243 - position 0 ,  7 - action: west
# step 244 - position 0 ,  6 - action: west
# step 245 - position 0 ,  5 - action: west
# step 246 - position 0 ,  4 - action: east
# step 247 - position 0 ,  5 - action: west
# step 248 - position 0 ,  4 - action: east
# step 249 - position 0 ,  5 - action: west
# step 250 - position 0 ,  4 - action: west
# step 251 - position 0 ,  3 - action: east
# step 252 - position 0 ,  4 - action: west
# step 253 - position 0 ,  3 - action: west
# step 254 - position 0 ,  2 - action: east
# step 255 - position 0 ,  3 - action: west
# step 256 - position 0 ,  2 - action: west
# step 257 - position 0 ,  1 - action: west
# step 258 - position 0 ,  0 - action: east
# step 259 - position 0 ,  1 - action: west
# step 260 - position 0 ,  0 - action: east
# step 261 - position 0 ,  1 - action: east
# step 262 - position 0 ,  2 - action: west
# step 263 - position 0 ,  1 - action: east
# step 264 - position 0 ,  2 - action: west
# step 265 - position 0 ,  1 - action: west
# step 266 - position 0 ,  0 - action: east
# step 267 - position 0 ,  1 - action: west
# step 268 - position 0 ,  0 - action: east
# step 269 - position 0 ,  1 - action: east
# step 270 - position 0 ,  2 - action: west
# step 271 - position 0 ,  1 - action: east
# step 272 - position 0 ,  2 - action: east
# step 273 - position 0 ,  3 - action: west
# step 274 - position 0 ,  2 - action: east
# ...
# step 328 - position 0 ,  9 - action: suck
# step 329 - position 0 ,  9 - action: suck
# step 330 - position 0 ,  9 - action: suck
# step 331 - position 0 ,  9 - action: suck
# step 332 - position 0 ,  9 - action: suck
# step 333 - position 0 ,  9 - action: suck
# step 334 - position 0 ,  9 - action: suck
# step 335 - position 0 ,  9 - action: suck
# step 336 - position 0 ,  9 - action: suck
# step 337 - position 0 ,  9 - action: suck
# step 338 - position 0 ,  9 - action: suck
# step 339 - position 0 ,  9 - action: suck
# step 340 - position 0 ,  9 - action: suck
# step 341 - position 0 ,  9 - action: suck
# step 342 - position 0 ,  9 - action: suck
# step 343 - position 0 ,  9 - action: suck
# step 344 - position 0 ,  9 - action: suck
# step 345 - position 0 ,  9 - action: suck
# step 346 - position 0 ,  9 - action: suck
# step 347 - position 0 ,  9 - action: suck
# step 348 - position 0 ,  9 - action: suck
# step 349 - position 0 ,  9 - action: suck
# step 350 - position 0 ,  9 - action: suck
# step 351 - position 0 ,  9 - action: suck
# step 352 - position 0 ,  9 - action: suck
# step 353 - position 0 ,  9 - action: suck
# step 354 - position 0 ,  9 - action: suck
# step 355 - position 0 ,  9 - action: suck
# step 356 - position 0 ,  9 - action: suck
# step 357 - position 0 ,  9 - action: suck
# step 358 - position 0 ,  9 - action: suck
# step 359 - position 0 ,  9 - action: suck
# step 360 - position 0 ,  9 - action: suck
# step 361 - position 0 ,  9 - action: suck
# step 362 - position 0 ,  9 - action: suck
# step 363 - position 0 ,  9 - action: suck
# step 364 - position 0 ,  9 - action: suck
# step 365 - position 0 ,  9 - action: suck
# step 366 - position 0 ,  9 - action: suck
# step 367 - position 0 ,  9 - action: suck
# step 368 - position 0 ,  9 - action: suck
# step 369 - position 0 ,  9 - action: suck
# step 370 - position 0 ,  9 - action: suck
# step 371 - position 0 ,  9 - action: suck
# step 372 - position 0 ,  9 - action: suck
# step 373 - position 0 ,  9 - action: suck
# step 374 - position 0 ,  9 - action: suck
# step 375 - position 0 ,  9 - action: suck
# step 376 - position 0 ,  9 - action: suck
# step 377 - position 0 ,  9 - action: suck
# step 378 - position 0 ,  9 - action: suck
# step 379 - position 0 ,  9 - action: suck
# step 380 - position 0 ,  9 - action: suck
# step 381 - position 0 ,  9 - action: suck
# step 382 - position 0 ,  9 - action: suck
# step 383 - position 0 ,  9 - action: suck
# step 384 - position 0 ,  9 - action: suck
# step 385 - position 0 ,  9 - action: suck
# step 386 - position 0 ,  9 - action: suck
# step 387 - position 0 ,  9 - action: suck
# step 388 - position 0 ,  9 - action: suck
# step 389 - position 0 ,  9 - action: suck
# step 390 - position 0 ,  9 - action: suck
# step 391 - position 0 ,  9 - action: suck
# step 392 - position 0 ,  9 - action: suck
# step 393 - position 0 ,  9 - action: suck
# step 394 - position 0 ,  9 - action: suck
# step 395 - position 0 ,  9 - action: suck
# step 396 - position 0 ,  9 - action: suck
# step 397 - position 0 ,  9 - action: suck
# step 398 - position 0 ,  9 - action: suck
# step 399 - position 0 ,  9 - action: suck
# step 400 - position 0 ,  9 - action: suck
# step 401 - position 0 ,  9 - action: suck
# step 402 - position 0 ,  9 - action: suck
# step 403 - position 0 ,  9 - action: suck
# step 404 - position 0 ,  9 - action: suck
# step 405 - position 0 ,  9 - action: suck
# step 406 - position 0 ,  9 - action: suck
# step 407 - position 0 ,  9 - action: suck
# step 408 - position 0 ,  9 - action: suck
# step 409 - position 0 ,  9 - action: suck
# step 410 - position 0 ,  9 - action: suck
# step 411 - position 0 ,  9 - action: suck
# step 412 - position 0 ,  9 - action: suck
# step 413 - position 0 ,  9 - action: suck
# step 414 - position 0 ,  9 - action: suck
# step 415 - position 0 ,  9 - action: suck
# step 416 - position 0 ,  9 - action: suck
# step 417 - position 0 ,  9 - action: suck
# step 418 - position 0 ,  9 - action: suck
# step 419 - position 0 ,  9 - action: suck
# step 420 - position 0 ,  9 - action: suck
# step 421 - position 0 ,  9 - action: suck
# step 422 - position 0 ,  9 - action: suck
# step 423 - position 0 ,  9 - action: suck
# step 424 - position 0 ,  9 - action: suck
# step 425 - position 0 ,  9 - action: suck
# step 426 - position 0 ,  9 - action: suck
# step 427 - position 0 ,  9 - action: suck
# step 428 - position 0 ,  9 - action: suck
# step 429 - position 0 ,  9 - action: suck
# step 430 - position 0 ,  9 - action: suck
# step 431 - position 0 ,  9 - action: suck
# step 432 - position 0 ,  9 - action: suck
# step 433 - position 0 ,  9 - action: suck
# step 434 - position 0 ,  9 - action: suck
# step 435 - position 0 ,  9 - action: suck
# step 436 - position 0 ,  9 - action: suck
# step 437 - position 0 ,  9 - action: suck
# step 438 - position 0 ,  9 - action: suck
# step 439 - position 0 ,  9 - action: suck
# step 440 - position 0 ,  9 - action: suck
# step 441 - position 0 ,  9 - action: suck
# step 442 - position 0 ,  9 - action: suck
# step 443 - position 0 ,  9 - action: suck
# step 444 - position 0 ,  9 - action: suck
# step 445 - position 0 ,  9 - action: suck
# step 446 - position 0 ,  9 - action: suck
# step 447 - position 0 ,  9 - action: suck
# step 448 - position 0 ,  9 - action: suck
# step 449 - position 0 ,  9 - action: suck
# step 450 - position 0 ,  9 - action: suck
# step 451 - position 0 ,  9 - action: suck
# step 452 - position 0 ,  9 - action: suck
# step 453 - position 0 ,  9 - action: suck
# step 454 - position 0 ,  9 - action: suck
# step 455 - position 0 ,  9 - action: suck
# step 456 - position 0 ,  9 - action: suck
# step 457 - position 0 ,  9 - action: suck
# step 458 - position 0 ,  9 - action: suck
# step 459 - position 0 ,  9 - action: suck
# step 460 - position 0 ,  9 - action: suck
# step 461 - position 0 ,  9 - action: suck
# step 462 - position 0 ,  9 - action: suck
# step 463 - position 0 ,  9 - action: suck
# step 464 - position 0 ,  9 - action: suck
# step 465 - position 0 ,  9 - action: suck
# step 466 - position 0 ,  9 - action: suck
# step 467 - position 0 ,  9 - action: suck
# step 468 - position 0 ,  9 - action: suck
# step 469 - position 0 ,  9 - action: suck
# step 470 - position 0 ,  9 - action: suck
# step 471 - position 0 ,  9 - action: suck
# step 472 - position 0 ,  9 - action: suck
# step 473 - position 0 ,  9 - action: suck
# step 474 - position 0 ,  9 - action: suck
# step 475 - position 0 ,  9 - action: suck
# step 476 - position 0 ,  9 - action: suck
# step 477 - position 0 ,  9 - action: suck
# step 478 - position 0 ,  9 - action: suck
# step 479 - position 0 ,  9 - action: suck
# step 480 - position 0 ,  9 - action: suck
# step 481 - position 0 ,  9 - action: suck
# step 482 - position 0 ,  9 - action: suck
# step 483 - position 0 ,  9 - action: suck
# step 484 - position 0 ,  9 - action: suck
# step 485 - position 0 ,  9 - action: suck
# step 486 - position 0 ,  9 - action: suck
# step 487 - position 0 ,  9 - action: suck
# step 488 - position 0 ,  9 - action: suck
# step 489 - position 0 ,  9 - action: suck
# step 490 - position 0 ,  9 - action: suck
# step 491 - position 0 ,  9 - action: suck
# step 492 - position 0 ,  9 - action: suck
# step 493 - position 0 ,  9 - action: suck
# step 494 - position 0 ,  9 - action: suck
# step 495 - position 0 ,  9 - action: suck
# step 496 - position 0 ,  9 - action: suck
# step 497 - position 0 ,  9 - action: suck
# step 498 - position 0 ,  9 - action: suck
# step 499 - position 0 ,  9 - action: suck
# step 0 - position 1 ,  38 - action: east
# step 1 - position 1 ,  39 - action: suck
# step 2 - position 1 ,  39 - action: south
# step 3 - position 2 ,  39 - action: north
# step 4 - position 1 ,  39 - action: north
# step 5 - position 0 ,  39 - action: east
# step 6 - position 0 ,  40 - action: west
# step 7 - position 0 ,  39 - action: south
# step 8 - position 1 ,  39 - action: suck
# step 9 - position 1 ,  39 - action: suck
# step 10 - position 1 ,  39 - action: east
# step 11 - position 1 ,  40 - action: west
# step 12 - position 1 ,  39 - action: west
# step 13 - position 1 ,  38 - action: south
# step 14 - position 2 ,  38 - action: north
# step 15 - position 1 ,  38 - action: east
# step 16 - position 1 ,  39 - action: east
# step 17 - position 1 ,  40 - action: north
# step 18 - position 0 ,  40 - action: west
# step 19 - position 0 ,  39 - action: suck
# step 20 - position 0 ,  39 - action: north
# step 21 - position 0 ,  39 - action: suck
# step 22 - position 0 ,  39 - action: east
# step 23 - position 0 ,  40 - action: south
# step 24 - position 1 ,  40 - action: south
# step 25 - position 2 ,  40 - action: south
# step 26 - position 3 ,  40 - action: east
# step 27 - position 3 ,  41 - action: west
# step 28 - position 3 ,  40 - action: suck
# step 29 - position 3 ,  40 - action: suck
# step 30 - position 3 ,  40 - action: north
# step 31 - position 2 ,  40 - action: west
# step 32 - position 2 ,  39 - action: north
# step 33 - position 1 ,  39 - action: south
# step 34 - position 2 ,  39 - action: east
# step 35 - position 2 ,  40 - action: east
# step 36 - position 2 ,  41 - action: west
# step 37 - position 2 ,  40 - action: north
# step 38 - position 1 ,  40 - action: south
# step 39 - position 2 ,  40 - action: north
# step 40 - position 1 ,  40 - action: east
# step 41 - position 1 ,  41 - action: south
# step 42 - position 2 ,  41 - action: east
# step 43 - position 2 ,  42 - action: west
# step 44 - position 2 ,  41 - action: west
# step 45 - position 2 ,  40 - action: west
# step 46 - position 2 ,  39 - action: east
# step 47 - position 2 ,  40 - action: suck
# step 48 - position 2 ,  40 - action: suck
# step 49 - position 2 ,  40 - action: north
# step 50 - position 1 ,  40 - action: east
# step 51 - position 1 ,  41 - action: east
# step 52 - position 1 ,  42 - action: north
# step 53 - position 0 ,  42 - action: suck
# step 54 - position 0 ,  42 - action: west
# step 55 - position 0 ,  41 - action: south
# step 56 - position 1 ,  41 - action: north
# step 57 - position 0 ,  41 - action: east
# step 58 - position 0 ,  42 - action: south
# step 59 - position 1 ,  42 - action: west
# step 60 - position 1 ,  41 - action: east
# step 61 - position 1 ,  42 - action: north
# step 62 - position 0 ,  42 - action: suck
# step 63 - position 0 ,  42 - action: west
# step 64 - position 0 ,  41 - action: suck
# step 65 - position 0 ,  41 - action: west
# step 66 - position 0 ,  40 - action: east
# step 67 - position 0 ,  41 - action: north
# step 68 - position 0 ,  41 - action: suck
# step 69 - position 0 ,  41 - action: north
# step 70 - position 0 ,  41 - action: suck
# step 71 - position 0 ,  41 - action: suck
# step 72 - position 0 ,  41 - action: north
# step 73 - position 0 ,  41 - action: suck
# step 74 - position 0 ,  41 - action: west
# step 75 - position 0 ,  40 - action: east
# step 76 - position 0 ,  41 - action: west
# step 77 - position 0 ,  40 - action: north
# step 78 - position 0 ,  40 - action: east
# step 79 - position 0 ,  41 - action: east
# step 80 - position 0 ,  42 - action: west
# step 81 - position 0 ,  41 - action: south
# step 82 - position 1 ,  41 - action: suck
# step 83 - position 1 ,  41 - action: north
# step 84 - position 0 ,  41 - action: east
# step 85 - position 0 ,  42 - action: west
# step 86 - position 0 ,  41 - action: south
# step 87 - position 1 ,  41 - action: south
# step 88 - position 2 ,  41 - action: north
# step 89 - position 1 ,  41 - action: north
# step 90 - position 0 ,  41 - action: east
# step 91 - position 0 ,  42 - action: west
# step 92 - position 0 ,  41 - action: east
# step 93 - position 0 ,  42 - action: north
# step 94 - position 0 ,  42 - action: west
# step 95 - position 0 ,  41 - action: west
# step 96 - position 0 ,  40 - action: south
# step 97 - position 1 ,  40 - action: west
# step 98 - position 1 ,  39 - action: north
# step 99 - position 0 ,  39 - action: north
# step 100 - position 0 ,  39 - action: east
# step 101 - position 0 ,  40 - action: suck
# step 102 - position 0 ,  40 - action: south
# step 103 - position 1 ,  40 - action: north
# step 104 - position 0 ,  40 - action: east
# step 105 - position 0 ,  41 - action: north
# step 106 - position 0 ,  41 - action: north
# step 107 - position 0 ,  41 - action: east
# step 108 - position 0 ,  42 - action: north
# step 109 - position 0 ,  42 - action: west
# step 110 - position 0 ,  41 - action: suck
# step 111 - position 0 ,  41 - action: suck
# step 112 - position 0 ,  41 - action: east
# step 113 - position 0 ,  42 - action: east
# step 114 - position 0 ,  43 - action: suck
# step 115 - position 0 ,  43 - action: north
# step 116 - position 0 ,  43 - action: east
# step 117 - position 0 ,  44 - action: south
# step 118 - position 1 ,  44 - action: south
# step 119 - position 2 ,  44 - action: west
# step 120 - position 2 ,  43 - action: east
# step 121 - position 2 ,  44 - action: north
# step 122 - position 1 ,  44 - action: suck
# step 123 - position 1 ,  44 - action: north
# step 124 - position 0 ,  44 - action: suck
# step 125 - position 0 ,  44 - action: west
# step 126 - position 0 ,  43 - action: south
# step 127 - position 1 ,  43 - action: west
# step 128 - position 1 ,  42 - action: suck
# step 129 - position 1 ,  42 - action: east
# step 130 - position 1 ,  43 - action: suck
# step 131 - position 1 ,  43 - action: south
# step 132 - position 2 ,  43 - action: south
# step 133 - position 3 ,  43 - action: east
# step 134 - position 3 ,  44 - action: south
# step 135 - position 4 ,  44 - action: suck
# step 136 - position 4 ,  44 - action: south
# step 137 - position 5 ,  44 - action: south
# step 138 - position 6 ,  44 - action: suck
# step 139 - position 6 ,  44 - action: north
# step 140 - position 5 ,  44 - action: east
# step 141 - position 5 ,  45 - action: east
# step 142 - position 5 ,  46 - action: north
# step 143 - position 4 ,  46 - action: south
# step 144 - position 5 ,  46 - action: north
# step 145 - position 4 ,  46 - action: east
# step 146 - position 4 ,  47 - action: west
# step 147 - position 4 ,  46 - action: east
# step 148 - position 4 ,  47 - action: west
# step 149 - position 4 ,  46 - action: west
# step 150 - position 4 ,  45 - action: suck
# step 151 - position 4 ,  45 - action: west
# step 152 - position 4 ,  44 - action: south
# step 153 - position 5 ,  44 - action: north
# step 154 - position 4 ,  44 - action: north
# step 155 - position 3 ,  44 - action: north
# step 156 - position 2 ,  44 - action: suck
# step 157 - position 2 ,  44 - action: north
# step 158 - position 1 ,  44 - action: east
# step 159 - position 1 ,  45 - action: south
# step 160 - position 2 ,  45 - action: suck
# step 161 - position 2 ,  45 - action: north
# step 162 - position 1 ,  45 - action: north
# step 163 - position 0 ,  45 - action: suck
# step 164 - position 0 ,  45 - action: east
# step 165 - position 0 ,  46 - action: north
# step 166 - position 0 ,  46 - action: east
# step 167 - position 0 ,  47 - action: west
# step 168 - position 0 ,  46 - action: east
# step 169 - position 0 ,  47 - action: east
# step 170 - position 0 ,  48 - action: suck
# step 171 - position 0 ,  48 - action: suck
# step 172 - position 0 ,  48 - action: suck
# step 173 - position 0 ,  48 - action: west
# step 174 - position 0 ,  47 - action: west
# step 175 - position 0 ,  46 - action: east
# step 176 - position 0 ,  47 - action: east
# step 177 - position 0 ,  48 - action: west
# step 178 - position 0 ,  47 - action: north
# step 179 - position 0 ,  47 - action: south
# step 180 - position 1 ,  47 - action: suck
# step 181 - position 1 ,  47 - action: north
# step 182 - position 0 ,  47 - action: east
# step 183 - position 0 ,  48 - action: suck
# step 184 - position 0 ,  48 - action: east
# step 185 - position 0 ,  49 - action: north
# step 186 - position 0 ,  49 - action: south
# step 187 - position 1 ,  49 - action: north
# step 188 - position 0 ,  49 - action: suck
# step 189 - position 0 ,  49 - action: north
# step 190 - position 0 ,  49 - action: west
# step 191 - position 0 ,  48 - action: suck
# step 192 - position 0 ,  48 - action: suck
# step 193 - position 0 ,  48 - action: south
# step 194 - position 1 ,  48 - action: north
# step 195 - position 0 ,  48 - action: south
# step 196 - position 1 ,  48 - action: north
# step 197 - position 0 ,  48 - action: south
# step 198 - position 1 ,  48 - action: east
# step 199 - position 1 ,  49 - action: west
# step 200 - position 1 ,  48 - action: north
# step 201 - position 0 ,  48 - action: south
# step 202 - position 1 ,  48 - action: east
# step 203 - position 1 ,  49 - action: suck

# %%
obst_avgs

# %% [markdown]
# ## More advanced tasks to think about
#
# You can think about these:
#
# * __Unknown environment with obstacles:__ Implement an agent for an environment where the agent does not know how large the environment is (we assume it is rectangular), where it starts or where the obstacles are. An option would be to always move to the closest unchecked/uncleaned square.
#
# * __Utility-based agent:__ Change the environment, so each square has a fixed probability of getting dirty again. We assume the agent has learned this information over time. For the implementation, we give this information to the agent as a 2-dimensional array of probabilities  Cleaning one dirty square produces a utility of 1. Implement a utility-based agent that maximizes the expected utility over one full charge which lasts for 10000 time steps. This is very tricky!

# %%
# Your ideas/code
